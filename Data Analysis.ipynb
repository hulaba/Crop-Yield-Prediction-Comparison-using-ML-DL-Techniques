# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
crop = pd.read_excel("Final_Dataset_Minor_Project.xlsx")

# %%
df = pd.DataFrame(crop)

# %%
df.head()
# Out:
#        State District  Year  Season               Crop    Area  Production  \
# 0  Rajasthan    Ajmer  1997  Kharif              Bajra   56600     30400.0
# 1  Rajasthan    Ajmer  1997  Kharif              Jowar  105900     34600.0
# 2  Rajasthan    Ajmer  1997    Rabi             Barley   24700     28900.0
# 3  Rajasthan    Ajmer  1997    Rabi  Rapeseed &Mustard   36700     25400.0
# 4  Rajasthan    Ajmer  1997    Rabi              Wheat   79300    144500.0
#
#       Yield   Predominantly reddish medium texture   Red desert soils  ...  \
# 0  0.537102                                      0                  0  ...
# 1  0.326723                                      0                  0  ...
# 2  1.170040                                      0                  0  ...
# 3  0.692098                                      0                  0  ...
# 4  1.822194                                      0                  0  ...
#
#    April     May    June     July   August  September  October  November  \
# 0  1.791  14.522  93.433  129.173  281.991     76.899    22.97     53.27
# 1  1.791  14.522  93.433  129.173  281.991     76.899    22.97     53.27
# 2  1.791  14.522  93.433  129.173  281.991     76.899    22.97     53.27
# 3  1.791  14.522  93.433  129.173  281.991     76.899    22.97     53.27
# 4  1.791  14.522  93.433  129.173  281.991     76.899    22.97     53.27
#
#    December  Annual Total
# 0     6.612       685.217
# 1     6.612       685.217
# 2     6.612       685.217
# 3     6.612       685.217
# 4     6.612       685.217
#
# [5 rows x 48 columns]

# %%
df.Crop.value_counts()
# Out:
# Wheat                733
# Rapeseed &Mustard    733
# Barley               732
# Bajra                726
# Jowar                724
# Name: Crop, dtype: int64

# %%
def data_graph (axis, width, height):
    axis.spines['top'].set_visible(False)
    axis.spines['right'].set_visible(False)
    for p in axis.patches:
        axis.annotate ("{0:.1f}".format(p.get_height()), (p.get_x()+width, p.get_height()+height))

# %%
plt.figure(figsize = (10,6))

ax = sns.lineplot(x=df.Year, y=df.Area)
plt.xticks(rotation = 60, ha = "right")
plt.ylabel("Area")
plt.xlabel("Year")

plt.show()

# %%
plt.figure(figsize = (10,6))
ax = sns.lineplot(x=df.Year, y=df.Yield)
plt.xticks(rotation = 60, ha = "right")
plt.ylabel("Yield")
plt.xlabel("Year")

plt.show()

# %%
plt.figure(figsize = (10,6))
ax = sns.lineplot(x=df.Year, y=df["Annual Total"])
plt.xticks(rotation = 45, ha = "right")
plt.ylabel("Annual Rainfall")
plt.xlabel("Year")

plt.show()

# %%
plt.figure(figsize=(10,5))
bajra_df = df[df["Crop"]=="Bajra"]
sns.lineplot("Year","Area",data=bajra_df)
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(10,5))
bajra_df = df[df["Crop"]=="Bajra"]
sns.lineplot("Year","Yield",data=bajra_df)
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(10,5))
wheat_df = df[df["Crop"]=="Wheat"]
sns.lineplot("Year","Area",data=wheat_df)
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(10,5))
wheat_df = df[df["Crop"]=="Wheat"]
sns.lineplot("Year","Yield",data=wheat_df)
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(10,5))
rnm_df = df[df["Crop"]=="Rapeseed &Mustard"]
sns.lineplot("Year","Area",data=rnm_df)
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(10,5))
rnm_df = df[df["Crop"]=="Rapeseed &Mustard"]
sns.lineplot("Year","Yield",data=rnm_df)
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(10,5))
barley_df = df[df["Crop"]=="Barley"]
sns.lineplot("Year","Area",data=barley_df)
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(10,5))
barley_df = df[df["Crop"]=="Barley"]
sns.lineplot("Year","Yield",data=barley_df)
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(10,5))
jowar_df = df[df["Crop"]=="Jowar"]
sns.lineplot("Year","Area",data=jowar_df)
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(10,5))
jowar_df = df[df["Crop"]=="Jowar"]
sns.lineplot("Year","Yield",data=jowar_df)
plt.xticks(rotation=60)
plt.show()
